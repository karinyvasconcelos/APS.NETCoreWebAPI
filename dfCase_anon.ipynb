# %% [markdown]
# <a href="https://colab.research.google.com/github/karinyvasconcelos/APS.NETCoreWebAPI/blob/master/dfCase_anon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # lib to work with vectors
import pandas as pd # lib to work with dataframes
import seaborn as sns # lib to work with plots
import matplotlib.pyplot as plt # lib to plot similar to matlab

# %% [markdown]
# # Import data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9aa3a3d4-be6a-4fcb-b483-a80aef594d33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9aa3a3d4-be6a-4fcb-b483-a80aef594d33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# open csv file
data_frame_dfCase = pd.read_csv('dfCaseDS_anon.csv', sep=';')

# %%
data_frame_dfCase.head()
# Out:
#    COD_CICLO  FLG_DATA  COD_MATERIAL COD_CANAL DES_CATEGORIA_MATERIAL  \
# 0     201917         1        431148   anon_S0                anon_S2
# 1     202005         0        177816   anon_S0                anon_S2
# 2     201901         0        171786   anon_S0                anon_S5
# 3     201813         0        177774   anon_S7                anon_S2
# 4     202006         1        446592   anon_S0                anon_S5
#
#   DES_MARCA_MATERIAL COD_REGIAO QT_VENDA_BRUTO  QT_DEVOLUCAO VL_RECEITA_BRUTA  \
# 0            anon_S3    anon_S1   11934,000000         414.0    431869,080000
# 1            anon_S4    anon_S1     540,000000         252.0     27743,400000
# 2            anon_S6    anon_S1   54012,000000        1410.0    962860,200000
# 3            anon_S8    anon_S1     438,000000           NaN      7608,600000
# 4            anon_S9    anon_S1    2760,000000         240.0     83339,400000
#
#   VL_RECEITA_LIQUIDA  FLG_CAMPANHA_MKT_A  FLG_CAMPANHA_MKT_B  \
# ...

# %%
data_frame_dfCase.shape
# Out:
# (116972, 1)
